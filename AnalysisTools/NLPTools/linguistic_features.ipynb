# %%
import matplotlib as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/Linguistic_features.csv")

# %%
df.describe()
# Out:
#        # Areas before prompt (0-5 from identified areas)  Total words  \
# count                                          70.000000    70.000000
# mean                                            3.414286   303.628571
# std                                             0.985296    92.923714
# min                                             1.000000    79.000000
# 25%                                             3.000000   232.500000
# 50%                                             3.000000   289.000000
# 75%                                             4.000000   357.500000
# max                                             5.000000   600.000000
#
#        # hesitations   # social  # prompts  Complexity  Task Performance  \
# count      70.000000  70.000000  70.000000   70.000000               0.0
# mean       10.542857   1.171429   4.214286    0.631714               NaN
# std         7.314242   1.035198   1.751958    0.091556               NaN
# ...

# %%
df_cookie = df[(df[])]
